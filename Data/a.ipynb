# %%
import pandas as pd
import gzip

# Specify the path to your compressed CSV file
file_path = "./dataset.csv"

# Use gzip to read the compressed CSV file
with gzip.open(file_path, 'rt', encoding='utf-8') as file:
    df = pd.read_csv(file)

# Assuming 'dataset' is your DataFrame
numeric_columns = df.select_dtypes(include='number')
correlation_matrix = numeric_columns.corr()

# Print or use the correlation matrix as needed
print(correlation_matrix)
# Out:
#                      RecipeId  CookTime  PrepTime  TotalTime  Calories  \
# RecipeId             1.000000 -0.002301  0.002736  -0.002207  0.013661
# CookTime            -0.002301  1.000000  0.010716   0.999432 -0.002354
# PrepTime             0.002736  0.010716  1.000000   0.044408  0.000024
# TotalTime           -0.002207  0.999432  0.044408   1.000000 -0.002350
# Calories             0.013661 -0.002354  0.000024  -0.002350  1.000000
# FatContent           0.011802 -0.002554 -0.001678  -0.002608  0.767356
# SaturatedFatContent -0.008257 -0.002542 -0.001651  -0.002595  0.603317
# CholesterolContent   0.000184 -0.001789 -0.001415  -0.001834  0.478934
# SodiumContent        0.018555 -0.002000  0.003186  -0.001891  0.501082
# CarbohydrateContent  0.011324 -0.001673  0.000648  -0.001649  0.711640
# FiberContent         0.041741 -0.001709  0.004054  -0.001570  0.458711
# SugarContent        -0.018924  0.000261 -0.000389   0.000249  0.180895
# ProteinContent       0.007422 -0.001920 -0.000337  -0.001929  0.689447
#
#                      FatContent  SaturatedFatContent  CholesterolContent  \
# RecipeId               0.011802            -0.008257            0.000184
# CookTime              -0.002554            -0.002542           -0.001789
# PrepTime              -0.001678            -0.001651           -0.001415
# TotalTime             -0.002608            -0.002595           -0.001834
# Calories               0.767356             0.603317            0.478934
# FatContent             1.000000             0.767357            0.440515
# SaturatedFatContent    0.767357             1.000000            0.512186
# CholesterolContent     0.440515             0.512186            1.000000
# SodiumContent          0.381944             0.319671            0.335843
# CarbohydrateContent    0.223549             0.176623            0.066104
# FiberContent           0.192142             0.044003           -0.047346
# SugarContent           0.042603             0.090721           -0.036112
# ProteinContent         0.468088             0.388618            0.675302
#
#                      SodiumContent  CarbohydrateContent  FiberContent  \
# RecipeId                  0.018555             0.011324      0.041741
# CookTime                 -0.002000            -0.001673     -0.001709
# PrepTime                  0.003186             0.000648      0.004054
# TotalTime                -0.001891            -0.001649     -0.001570
# Calories                  0.501082             0.711640      0.458711
# FatContent                0.381944             0.223549      0.192142
# SaturatedFatContent       0.319671             0.176623      0.044003
# CholesterolContent        0.335843             0.066104     -0.047346
# SodiumContent             1.000000             0.294636      0.260479
# CarbohydrateContent       0.294636             1.000000      0.580535
# FiberContent              0.260479             0.580535      1.000000
# SugarContent             -0.055518             0.390120      0.068758
# ProteinContent            0.500457             0.255447      0.273488
#
#                      SugarContent  ProteinContent
# RecipeId                -0.018924        0.007422
# CookTime                 0.000261       -0.001920
# PrepTime                -0.000389       -0.000337
# TotalTime                0.000249       -0.001929
# Calories                 0.180895        0.689447
# FatContent               0.042603        0.468088
# SaturatedFatContent      0.090721        0.388618
# CholesterolContent      -0.036112        0.675302
# SodiumContent           -0.055518        0.500457
# CarbohydrateContent      0.390120        0.255447
# FiberContent             0.068758        0.273488
# SugarContent             1.000000       -0.120441
# ProteinContent          -0.120441        1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
